# %%
planets = ["水", "金", "地", "火", "木", "土", "天", "海", "冥"]

for p in planets:
    print(p)


i = 0
while i < len(planets):
    print(planets[i])
    i += 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
