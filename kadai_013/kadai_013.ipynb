# %%
def calculate_price_with_tax(price, tax):
    total = price + price * tax / 100
    return total


price = 110
tax = 10


result = calculate_price_with_tax(price, tax)


print(result)
# Out:
# 121.0
