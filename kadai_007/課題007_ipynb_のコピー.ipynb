# %%
from os import WEXITED
array=["月曜日は晴れです","火曜日は雨です","水曜日は晴れです","木曜日は晴れです","金曜日は曇りです","土曜日は曇りのち雨です","日曜日は雷雨です"]
print(array[2])

dictionary={1:"mon:晴れ",2:"the:雨",3:"wed:晴れ",4:"thu:晴れ",5:"fri:曇り",6:"sat:曇りのち雨",7:"sun:雷雨"}
print(dictionary[3])
# Out:
# 水曜日は晴れです
# wed:晴れ
